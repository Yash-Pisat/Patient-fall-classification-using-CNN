# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from pathlib import Path

from scipy.signal import stft

from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten

BASEDIR = Path("/store/projects/fallki/")
FAKEDIR = BASEDIR / "Fake-Events" / "2. Fake-Events Messung"

# %% [markdown]
# # Data preparation
# In this notebook we try to train a deep neural network to seperate Dummy falls from the other fall events by training it on the stft picture we generate for all of them.

# %%
def SignalToSpectrum(signal, samplerate=1600):
    SIGNAL_LENGTH = samplerate * 10
    F = stft(signal[:SIGNAL_LENGTH], 1600, nperseg=128)[2]
    F = F[2:,]
    return np.expand_dims(np.abs(F), axis=2) # Add extra dimension for TF Conv2D

# %%
fakeEvents = pd.read_parquet(FAKEDIR / "gSensoren_FakeEvents.parquet")

# %%
L = []
for (teensy, event, run, rep), ss in fakeEvents.groupby(["teensy", "experiment", "run", "rep"]):
    L.append({"event": event,
              "run": run,
              "istSturz": int(event == "Dummy"),
              "signalLenght": len(ss["z"]),
              "spectrum": SignalToSpectrum(ss["z"])})
df = pd.DataFrame.from_dict(L)

# %%
df.head()
# Out:
#           event run  istSturz  signalLenght  \
# 0  1.5L Flasche  L1         0         15976
# 1  1.5L Flasche  L1         0         16038
# 2  1.5L Flasche  L1         0         15997
# 3  1.5L Flasche  L2         0         15994
# 4  1.5L Flasche  L2         0         15981
#
#                                             spectrum
# 0  [[[220.68784142956994], [0.11347713586453584],...
# 1  [[[220.7760221941459], [0.4810628935081976], [...
# 2  [[[220.56718777220033], [0.12610317723679612],...
# 3  [[[220.36006931821052], [0.1674748618352673], ...
# 4  [[[220.2963925540494], [0.10592890921923297], ...

# %%
# normalize the spectrum to facilitate training
df["normalizedSpectrum"] = df["spectrum"] / df["spectrum"].map(np.max).max()

# %% [markdown]
# # Model

# %%
mdl = Sequential()
mdl.add(Conv2D(8, (63, 5), activation="relu", input_shape=(63, 251, 1)))
mdl.add(MaxPooling2D((1, 4)))
#mdl.add(Dense(1))
mdl.add(Flatten())
mdl.add(Dense(1))
mdl.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
mdl.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 1, 247, 8)         2528
#
#  max_pooling2d_4 (MaxPooling  (None, 1, 61, 8)         0
#  2D)
#
#  flatten_4 (Flatten)         (None, 488)               0
#
#  dense_4 (Dense)             (None, 1)                 489
#
# =================================================================
# Total params: 3,017
# Trainable params: 3,017
# Non-trainable params: 0
# _________________________________________________________________

# %%
X = np.stack(df["normalizedSpectrum"].to_list())
y = df["istSturz"].to_numpy()

# split data in train and test set
train, test = train_test_split(range(len(y)), test_size=0.2)
# how many of the respective events are contained in the test set
df["event"][test].value_counts()
# Out:
# Springen               20
# 2 Bücher               19
# Stuhl kippt            18
# Handy                  16
# Getränkeflasche        16
# 1.5L Flasche           16
# Möbel verrücken        15
# Schlüsselbund          14
# Krücken                14
# Hantel                 13
# Tablett mit Besteck    13
# Wasserkasten           12
# Dummy                  11
# Koffer                 11
# Pflegeartikel           8
# Name: event, dtype: int64

# %%
# actual training..
history = mdl.fit(X[train, ], y[train], epochs=75, validation_data=(X[test,], y[test]))
# Out:
# Epoch 1/75
# 27/27 [==============================] - 1s 13ms/step - loss: 0.2873 - accuracy: 0.9293 - val_loss: 0.2064 - val_accuracy: 0.9491
# Epoch 2/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.2463 - accuracy: 0.9293 - val_loss: 0.1993 - val_accuracy: 0.9491
# Epoch 3/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.2396 - accuracy: 0.9293 - val_loss: 0.1936 - val_accuracy: 0.9491
# Epoch 4/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.2314 - accuracy: 0.9293 - val_loss: 0.1869 - val_accuracy: 0.9491
# Epoch 5/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.2192 - accuracy: 0.9293 - val_loss: 0.1733 - val_accuracy: 0.9491
# Epoch 6/75
# 27/27 [==============================] - 0s 10ms/step - loss: 0.2085 - accuracy: 0.9293 - val_loss: 0.1723 - val_accuracy: 0.9491
# Epoch 7/75
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1946 - accuracy: 0.9293 - val_loss: 0.1559 - val_accuracy: 0.9491
# Epoch 8/75
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1821 - accuracy: 0.9305 - val_loss: 0.1504 - val_accuracy: 0.9444
# Epoch 9/75
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1697 - accuracy: 0.9328 - val_loss: 0.1383 - val_accuracy: 0.9444
# Epoch 10/75
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1582 - accuracy: 0.9328 - val_loss: 0.1325 - val_accuracy: 0.9444
# Epoch 11/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1503 - accuracy: 0.9316 - val_loss: 0.1267 - val_accuracy: 0.9444
# Epoch 12/75
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1442 - accuracy: 0.9328 - val_loss: 0.1243 - val_accuracy: 0.9444
# Epoch 13/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1374 - accuracy: 0.9363 - val_loss: 0.1184 - val_accuracy: 0.9444
# Epoch 14/75
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1323 - accuracy: 0.9397 - val_loss: 0.1185 - val_accuracy: 0.9444
# Epoch 15/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1288 - accuracy: 0.9409 - val_loss: 0.1139 - val_accuracy: 0.9444
# Epoch 16/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1238 - accuracy: 0.9421 - val_loss: 0.1093 - val_accuracy: 0.9444
# Epoch 17/75
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1210 - accuracy: 0.9432 - val_loss: 0.1081 - val_accuracy: 0.9444
# Epoch 18/75
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1166 - accuracy: 0.9479 - val_loss: 0.1044 - val_accuracy: 0.9491
# Epoch 19/75
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1132 - accuracy: 0.9490 - val_loss: 0.1039 - val_accuracy: 0.9444
# Epoch 20/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1105 - accuracy: 0.9490 - val_loss: 0.0992 - val_accuracy: 0.9491
# Epoch 21/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1082 - accuracy: 0.9490 - val_loss: 0.0991 - val_accuracy: 0.9444
# Epoch 22/75
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1043 - accuracy: 0.9502 - val_loss: 0.0966 - val_accuracy: 0.9444
# Epoch 23/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1019 - accuracy: 0.9513 - val_loss: 0.0960 - val_accuracy: 0.9444
# Epoch 24/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0996 - accuracy: 0.9513 - val_loss: 0.0927 - val_accuracy: 0.9444
# Epoch 25/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0985 - accuracy: 0.9525 - val_loss: 0.0916 - val_accuracy: 0.9444
# Epoch 26/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0959 - accuracy: 0.9513 - val_loss: 0.0904 - val_accuracy: 0.9491
# Epoch 27/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0937 - accuracy: 0.9513 - val_loss: 0.0895 - val_accuracy: 0.9491
# Epoch 28/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0917 - accuracy: 0.9525 - val_loss: 0.0889 - val_accuracy: 0.9491
# Epoch 29/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0898 - accuracy: 0.9560 - val_loss: 0.0859 - val_accuracy: 0.9491
# Epoch 30/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0874 - accuracy: 0.9537 - val_loss: 0.0850 - val_accuracy: 0.9491
# Epoch 31/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0859 - accuracy: 0.9618 - val_loss: 0.0839 - val_accuracy: 0.9491
# Epoch 32/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0841 - accuracy: 0.9571 - val_loss: 0.0828 - val_accuracy: 0.9491
# Epoch 33/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0825 - accuracy: 0.9629 - val_loss: 0.0814 - val_accuracy: 0.9491
# Epoch 34/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0806 - accuracy: 0.9618 - val_loss: 0.0802 - val_accuracy: 0.9491
# Epoch 35/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0785 - accuracy: 0.9618 - val_loss: 0.0803 - val_accuracy: 0.9583
# Epoch 36/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0774 - accuracy: 0.9641 - val_loss: 0.0785 - val_accuracy: 0.9491
# Epoch 37/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0760 - accuracy: 0.9664 - val_loss: 0.0778 - val_accuracy: 0.9537
# Epoch 38/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0743 - accuracy: 0.9652 - val_loss: 0.0774 - val_accuracy: 0.9583
# Epoch 39/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0728 - accuracy: 0.9652 - val_loss: 0.0762 - val_accuracy: 0.9583
# Epoch 40/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0714 - accuracy: 0.9687 - val_loss: 0.0756 - val_accuracy: 0.9630
# Epoch 41/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0714 - accuracy: 0.9676 - val_loss: 0.0763 - val_accuracy: 0.9630
# Epoch 42/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0687 - accuracy: 0.9687 - val_loss: 0.0739 - val_accuracy: 0.9630
# Epoch 43/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0676 - accuracy: 0.9710 - val_loss: 0.0732 - val_accuracy: 0.9630
# Epoch 44/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0669 - accuracy: 0.9699 - val_loss: 0.0738 - val_accuracy: 0.9630
# Epoch 45/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0651 - accuracy: 0.9733 - val_loss: 0.0722 - val_accuracy: 0.9630
# Epoch 46/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0652 - accuracy: 0.9699 - val_loss: 0.0719 - val_accuracy: 0.9630
# Epoch 47/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0640 - accuracy: 0.9791 - val_loss: 0.0707 - val_accuracy: 0.9630
# Epoch 48/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0618 - accuracy: 0.9768 - val_loss: 0.0699 - val_accuracy: 0.9630
# Epoch 49/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0613 - accuracy: 0.9745 - val_loss: 0.0695 - val_accuracy: 0.9630
# Epoch 50/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0596 - accuracy: 0.9780 - val_loss: 0.0691 - val_accuracy: 0.9630
# Epoch 51/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0587 - accuracy: 0.9803 - val_loss: 0.0678 - val_accuracy: 0.9630
# Epoch 52/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0579 - accuracy: 0.9791 - val_loss: 0.0678 - val_accuracy: 0.9630
# Epoch 53/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0569 - accuracy: 0.9803 - val_loss: 0.0663 - val_accuracy: 0.9630
# Epoch 54/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0557 - accuracy: 0.9803 - val_loss: 0.0659 - val_accuracy: 0.9630
# Epoch 55/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0553 - accuracy: 0.9791 - val_loss: 0.0670 - val_accuracy: 0.9676
# Epoch 56/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0540 - accuracy: 0.9826 - val_loss: 0.0641 - val_accuracy: 0.9630
# Epoch 57/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0530 - accuracy: 0.9815 - val_loss: 0.0642 - val_accuracy: 0.9630
# Epoch 58/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0534 - accuracy: 0.9815 - val_loss: 0.0632 - val_accuracy: 0.9630
# Epoch 59/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0515 - accuracy: 0.9838 - val_loss: 0.0627 - val_accuracy: 0.9630
# Epoch 60/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0501 - accuracy: 0.9838 - val_loss: 0.0625 - val_accuracy: 0.9676
# Epoch 61/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0494 - accuracy: 0.9838 - val_loss: 0.0618 - val_accuracy: 0.9630
# Epoch 62/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0486 - accuracy: 0.9849 - val_loss: 0.0613 - val_accuracy: 0.9722
# Epoch 63/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0475 - accuracy: 0.9838 - val_loss: 0.0609 - val_accuracy: 0.9722
# Epoch 64/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0472 - accuracy: 0.9849 - val_loss: 0.0609 - val_accuracy: 0.9722
# Epoch 65/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0463 - accuracy: 0.9849 - val_loss: 0.0601 - val_accuracy: 0.9722
# Epoch 66/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0457 - accuracy: 0.9838 - val_loss: 0.0593 - val_accuracy: 0.9722
# Epoch 67/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0456 - accuracy: 0.9849 - val_loss: 0.0589 - val_accuracy: 0.9676
# Epoch 68/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0446 - accuracy: 0.9826 - val_loss: 0.0583 - val_accuracy: 0.9722
# Epoch 69/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0433 - accuracy: 0.9838 - val_loss: 0.0578 - val_accuracy: 0.9722
# Epoch 70/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0432 - accuracy: 0.9838 - val_loss: 0.0574 - val_accuracy: 0.9722
# Epoch 71/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0433 - accuracy: 0.9838 - val_loss: 0.0568 - val_accuracy: 0.9722
# Epoch 72/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0420 - accuracy: 0.9838 - val_loss: 0.0583 - val_accuracy: 0.9722
# Epoch 73/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0415 - accuracy: 0.9838 - val_loss: 0.0580 - val_accuracy: 0.9722
# Epoch 74/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0404 - accuracy: 0.9838 - val_loss: 0.0561 - val_accuracy: 0.9722
# Epoch 75/75
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0397 - accuracy: 0.9838 - val_loss: 0.0557 - val_accuracy: 0.9722

# %%
df.istSturz.sum()
# Out:
# 72

# %% [markdown]
# ## Problems
# We do not have a large amount of training data, in total we have 1079 spectrum with only 72 positive samples.
# Even though we already went for a rather small model (3017 parameters) it is keen to overfit, thus one needs to be really careful during fitting the model.
#
# Ideally we would need more data, this data is currently recorded inside rooms of a retirement home, so far we (luckily) did not record any real fall events but this does not make training easier. Thus we need to augment our training data with different methods.

# %%
# here we evaluate our trained model on all of the data, by adjusting the threshold  value we can manually test how clear the separation between positive and negative events really is
# in the current state the model is heavily overfitted
ypred = mdl.predict(X).ravel()
threshold = 0.15
pd.crosstab(df['event'], ypred >= threshold)
# Out:
# 34/34 [==============================] - 0s 3ms/step
# col_0                False  True
# event
# 1.5L Flasche            61     11
# 2 Bücher                70      2
# Dummy                    0     72
# Getränkeflasche         71      1
# Handy                   72      0
# Hantel                  71      0
# Koffer                  72      0
# Krücken                 72      0
# Möbel verrücken         71      1
# Pflegeartikel           72      0
# Schlüsselbund           72      0
# Springen                71      1
# Stuhl kippt             67      5
# Tablett mit Besteck     72      0
# Wasserkasten            57     15
